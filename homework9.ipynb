# %% [markdown]
# <a href="https://colab.research.google.com/github/Junyu0321/fin_data/blob/main/homework9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fredapi

# %%
from fredapi import Fred

# %%
fred = Fred(api_key='e1cf045c94d49040be06cb5c7cd6458d')

# %%
expected_return = fred.get_series('IR14250')

# %%
unemployment_rate = fred.get_series('UNRATE')

# %%
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.plot(expected_return.index, expected_return.values, label="expected_return", color='blue')
plt.title('expected_return')
plt.xlabel('Year')
plt.ylabel('Num')
plt.grid(True)

plt.subplot(2, 1, 2)
plt.plot(unemployment_rate.index, unemployment_rate.values, label="unemployment_rate", color='red')
plt.title('unemployment_rate')
plt.xlabel('Year')
plt.ylabel('Num')
plt.grid(True)


plt.tight_layout()
plt.show()
