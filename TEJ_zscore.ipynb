# %% [markdown]
# <a href="https://colab.research.google.com/github/Junyu0321/fin_data/blob/main/TEJ_zscore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/Junyu0321/fin_data/main/sheet.csv"

# %%
df1 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df1
# Out:
#                 YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 6039 Next Bank  2023/12        4             N     12      NTD
# T2810 Banks     2023/12        4             Y     12      NTD
#
#                 Total cash and cash equivalents  \
# CO_ID
# 6039 Next Bank                          74499.0
# T2810 Banks                         962134388.0
#
#                 Total due from the central bank and call loans to banks  \
# CO_ID
# 6039 Next Bank                                       3.770109e+06
# T2810 Banks                                          4.278332e+09
#
#                 Total financial assets at fair value through profit or loss  \
# CO_ID
# 6039 Next Bank                                       0.000000e+00
# T2810 Banks                                          2.816565e+09
#
#                 Derivative financial assets, net  \
# CO_ID
# 6039 Next Bank                               0.0
# T2810 Banks                            7448711.0
#
# ...

# %%
url = "https://raw.githubusercontent.com/Junyu0321/fin_data/main/sheet.csv"

# %%
df2 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df2
# Out:
#                 YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 6039 Next Bank  2023/12        4             N     12      NTD
# T2810 Banks     2023/12        4             Y     12      NTD
#
#                 Total cash and cash equivalents  \
# CO_ID
# 6039 Next Bank                          74499.0
# T2810 Banks                         962134388.0
#
#                 Total due from the central bank and call loans to banks  \
# CO_ID
# 6039 Next Bank                                       3.770109e+06
# T2810 Banks                                          4.278332e+09
#
#                 Total financial assets at fair value through profit or loss  \
# CO_ID
# 6039 Next Bank                                       0.000000e+00
# T2810 Banks                                          2.816565e+09
#
#                 Derivative financial assets, net  \
# CO_ID
# 6039 Next Bank                               0.0
# T2810 Banks                            7448711.0
#
# ...

# %%
df1.columns
# Out:
# Index(['YYYY/MM', 'Quarter', 'consolidation', 'Month', 'Currency',
#        'Total cash and cash equivalents',
#        'Total due from the central bank and call loans to banks',
#        'Total financial assets at fair value through profit or loss',
#        'Derivative financial assets, net',
#        'Securities purchased under resell agreements, net', 'Receivables, net',
#        'Total current tax assets', 'Assets classified as held for sale, net',
#        'Discounts and loans, net',
#        'Financial assets at fair value through other comprehensive income, net',
#        'Financial assets measured at amortized cost, net',
#        'Investments measured by equity method, net', 'Restricted assets, net',
#        'Other financial assets, net', 'Total property, plant and equipment',
#        'Right of use assets', 'Investment property, net',
#        'Intangible assets, net', 'Total deferred tax assets',
#        'Other assets, net', 'Total assets',
# ...

# %%
df1.index
# Out:
# Index(['6039 Next Bank', 'T2810 Banks'], dtype='object', name='CO_ID')

# %%
A_1101 = (df1.loc['6039 Next Bank','Total current tax assets'] - df1.loc['6039 Next Bank','Total current tax liabilities'])/df1.loc['6039 Next Bank','Total assets']

# %%
A_1101
# Out:
# 0.0006766577158949671

# %%
X1 ='Total current tax assets'
X2 ='Total current tax liabilities'
X3 ='Total assets'
X4 ='Total retained earnings'
X5 ='Total unappropriated earnings'
X6 ='Total equity'
X7 ='Total liabilities'
X8 ='Total financial assets at fair value through profit or loss'
Next_Bank ='6039 Next Bank'
Banks ='T2810 Banks'

# %%
A_Next_Bank = (df1.loc[Next_Bank,X1] - df1.loc[Next_Bank,X2])/df1.loc[Next_Bank, X3]

# %%
df1[X4] = pd.to_numeric(df1[X4], errors='coerce')

# %%
B_Next_Bank = df1.loc[Next_Bank,X4]/df1.loc[Next_Bank, X3]

# %%
df2[X5] = pd.to_numeric(df2[X5], errors='coerce')
df1[X3] = pd.to_numeric(df1[X3], errors='coerce')

# %%
C_Next_Bank = df2.loc[Next_Bank,X5]/df1.loc[Next_Bank, X3]

# %%
D_Next_Bank = df1.loc[Next_Bank,X6]/df1.loc[Next_Bank, X7] #調整分子項定義，採用股東權益帳面價值

# %%
E_Next_Bank = df2.loc[Next_Bank,X8]/df1.loc[Next_Bank, X3]

# %%
Z_score_Next_Bank  = 1.2*A_Next_Bank  + 1.4*B_Next_Bank  + 3.3*C_Next_Bank  + 0.6*D_Next_Bank  +1.0*E_Next_Bank

# %%
Z_score_Next_Bank, A_Next_Bank, B_Next_Bank, C_Next_Bank, D_Next_Bank, E_Next_Bank
# Out:
# (nan, 0.0006766577158949671, nan, nan, 0.332826175510861, 0.0)

# %%
A_Banks = (df1.loc[Banks,X1] - df1.loc[Banks,X2])/df1.loc[Banks, X3]

# %%
B_Banks = df1.loc[Banks,X4]/df1.loc[Banks, X3]

# %%
C_Banks = df2.loc[Banks,X5]/df1.loc[Banks, X3]

# %%
D_Banks = df1.loc[Banks,X6]/df1.loc[Banks, X7]

# %%
E_Banks = df2.loc[Banks,X8]/df1.loc[Banks, X3]

# %%
Z_score_Banks = 1.2*A_Banks + 1.4*B_Banks + 3.3*C_Banks + 0.6*D_Banks +1.0*E_Banks

# %%
Z_score_Banks, A_Banks, B_Banks, C_Banks, D_Banks, E_Banks
# Out:
# (0.1581275775482221,
#  -0.00064079615904637,
#  0.028691188631848562,
#  0.006770217748368237,
#  0.07452483998243972,
#  0.05167224629541073)
